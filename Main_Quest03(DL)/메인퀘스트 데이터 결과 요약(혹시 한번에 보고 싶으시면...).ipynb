# %%
import pandas as pd

# %%
pd.read_csv('result.csv')
# Out:
#      구분   훈련샘플                 신경망(코드참조) 최적화방법    학습률  epoch  test_loss  \
# 0  1차시도    300  노드에 있는 기본 신경망(dense만 수정)  Adam    기본값     10      2.200
# 1  2차시도    600      drop out 및 신경망 깊이 수정   SGD    기본값     15      2.980
# 2  3차시도    600                  2차시도와 동일   SGD  0.001     25      1.930
# 3  4차시도   2100                  2차시도와 동일  Adam    기본값     20      2.123
# 4  5차시도  12000                  2차시도와 동일  Adam  0.001     20      3.744
# 5  6차시도  12000                  2차시도와 동일  Adam  0.002     25      4.150
# 6  7차시도  12000            신경망 깊이 더 깊게 수정  Adam  0.001     25      5.719
#
#    test_accuracy
# 0          0.496
# 1          0.413
# 2          0.319
# 3          0.576
# 4          0.606
# 5          0.610
# 6          0.626
